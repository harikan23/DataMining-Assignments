# %% [markdown]
# KMeans clustering on digits data.
#
# 1. Kmeans clustering using inbuilt libraries
#
# 2. Kmeans clustering from scratch

# %%
from time import time
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import datasets

# %% [markdown]
# Load digits data from datasets.

# %%
digits = datasets.load_digits(n_class=5) # digits from 0 to 4
x = digits.data
y = digits.target
print (x.shape)
# Out:
# (901, 64)

# %%
nImagesperRow=5
img=np.zeros((10*nImagesperRow, 10*nImagesperRow))
for i in range(nImagesperRow):
    im = 10 * i + 1
    for j in range(nImagesperRow):
        jm = 10 * j + 1
        img[im:im+8,jm:jm+8]=x[i*nImagesperRow+j].reshape((8,8))
plt.imshow(img, cmap=plt.cm.binary)

# %% [markdown]
# Dimensionality reduction using PCA. Number of components in PCA is 2

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=2)
X_PCA = pca.fit_transform(digits.data)
print(X_PCA.shape)
data1 = pd.DataFrame(X_PCA, columns = ['PCA1','PCA2'])
# Out:
# (901, 2)

# %%
plt.figure(figsize=(7,7))
plt.scatter(data1["PCA1"],data1["PCA2"])
plt.xlabel('PCA1')
plt.ylabel('PCA2')
plt.title('Data Distribution')
plt.show()

# %% [markdown]
# Kmeans clustering using inbuilt libraries.

# %%
#training k-means model
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=5)
kmeans.fit(data1)

#predictions from kmeans
pred = kmeans.predict(data1)
frame = pd.DataFrame(data1)
frame['cluster'] = pred
frame.columns = ['PCA1', 'PCA2', 'cluster']

#plotting results
color=['blue','green','cyan', 'black', 'red']
for k in range(0,5):
    data = frame[frame["cluster"]==k]
    plt.scatter(data["PCA1"],data["PCA2"],c=color[k])
plt.show()

# %% [markdown]
# Kmeans is applied on the streched data.

# %%
rng = np.random.RandomState(13)
data_stretched= pd.DataFrame(X_PCA, columns = ['PCA1','PCA2'])
X_stretched = np.dot(data_stretched, rng.randn(2, 2))
data_stretched_d= pd.DataFrame(X_stretched, columns = ['PCA1','PCA2'])

# %%
plt.figure(figsize=(7,7))
plt.scatter(data_stretched_d["PCA1"],data_stretched_d["PCA2"])
plt.xlabel('PCA1')
plt.ylabel('PCA2')
plt.title('Data Distribution')
plt.show()

# %% [markdown]
# From the below clustering output we can say that kmeans is not the best method for the data which is has different clsuter shape boudaries. Kmeans works best for the circular boundaries between the data points.

# %%
#training k-means model for sreched data
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=5)
kmeans.fit(data_stretched_d)

#predictions from kmeans
pred = kmeans.predict(data_stretched_d)
frame = pd.DataFrame(data_stretched_d)
frame['cluster'] = pred
frame.columns = ['PCA1', 'PCA2', 'cluster']

#plotting results
color=['blue','green','cyan', 'black', 'red']
for k in range(0,5):
    data = frame[frame["cluster"]==k]
    plt.scatter(data["PCA1"],data["PCA2"],c=color[k])
plt.show()

# %% [markdown]
# # **K- Means Clustering Algorithm from scratch**

# %%
from scipy.spatial.distance import cdist 

def kmeans(data, k, no_iterations):
  # randomly choosing index and centorids
  index = np.random.choice(len(data), k, replace=False)
  centroids = data[index,:]
  # find ditance between centroid and all other points
  distances = cdist(data, centroids, 'euclidean')
  # choose the nearest point 
  points = np.array([np.argmin(i) for i in distances])
  for itr in range(no_iterations):
    centroids_points= []
    for indx_points in range(k):
      temp_centroid = data[points==indx_points].mean(axis=0)
      centroids_points.append(temp_centroid)
    centroids_points = np.vstack(centroids_points)
    distances = cdist(data, centroids_points, 'euclidean')
    points = np.array([np.argmin(i) for i in distances])
  return points

# %%
target_labels = kmeans(X_PCA,5,1000)

# %%
frame = pd.DataFrame(X_PCA)
frame['cluster'] = target_labels
frame.columns = ['PCA1', 'PCA2', 'cluster']

#plotting results
color=['blue','green','cyan', 'black', 'red']
for k in range(0,5):
    data = frame[frame["cluster"]==k]
    plt.scatter(data["PCA1"],data["PCA2"],c=color[k])
plt.show()
